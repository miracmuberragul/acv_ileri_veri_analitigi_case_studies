# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
# Excel dosyasını yükle
file_path = 'elektrik_veri_hashed.xlsx'
xls = pd.ExcelFile(file_path)
# Sayfa isimlerini görüntüle
print("Sayfa isimleri:", xls.sheet_names)
# Her sayfayı ayrı DataFrame'e yükle
df_tahsilat = pd.read_excel(xls, sheet_name='Tahsilat')
df_tahsilat_1 = pd.read_excel(xls, sheet_name='Tahsilat 1')
df_tahakkuk = pd.read_excel(xls, sheet_name='Tahakkuk') # Hamamözü
df_tahakkuk_1 = pd.read_excel(xls, sheet_name='Tahakkuk 1') # Gümüşhacıköy
df_tahakkuk_2 = pd.read_excel(xls, sheet_name='Tahakkuk 2') # Göynücek
# Out:
# Sayfa isimleri: ['Tahsilat', 'Tahsilat 1', 'Tahakkuk', 'Tahakkuk 1', 'Tahakkuk 2']

# %% [markdown]
# İlk kısımda ilk datafrome olan Tahsilat ile info head tail shape benzersiz müşteri numarası ve diğer istenenler yapılacaktır.

# %%
#veri büyük olduğu için ilk on ve son on satıra bakmak istedim.
df_tahsilat.head(10)
# Out:
#              Şube            Kasa    İlçe  Söz.hsp.(bağımsız) Tahsilat Tarihi  \
# 0  Tayin edilmedi  Tayin edilmedi  TAŞOVA          4989745446      2023-11-06
# 1  Tayin edilmedi  Tayin edilmedi  TAŞOVA          4989745446      2024-06-26
# 2  Tayin edilmedi  Tayin edilmedi  TAŞOVA          4989745446      2024-07-10
# 3             PTT          PTT/PV  TAŞOVA          4254955886      2023-01-19
# 4             PTT          PTT/PV  TAŞOVA          4254955886      2023-02-17
# 5             PTT          PTT/PV  TAŞOVA          4254955886      2023-03-16
# 6             PTT          PTT/PV  TAŞOVA          4254955886      2023-04-17
# 7             PTT          PTT/PV  TAŞOVA          4254955886      2023-05-18
# 8             PTT          PTT/PV  TAŞOVA          4254955886      2023-06-16
# 9             PTT          PTT/PV  TAŞOVA          4254955886      2023-07-19
#
#    Nakit Tahsilat  Mahsuben Tahsilat  Kredi Kartı Tahsilatı  Banka Tahsilatı
# ...

# %%
df_tahsilat.tail(10)
# Out:
#                   Şube    Kasa          İlçe  Söz.hsp.(bağımsız)  \
# 636983  AKTİFBANK-BAYİ  BAY/PB        TAŞOVA          4307024410
# 636984  AKTİFBANK-BAYİ  BAY/PB        TAŞOVA          9745062207
# 636985  AKTİFBANK-BAYİ  BAY/PB  GÜMÜŞHACIKÖY          6795373051
# 636986  AKTİFBANK-BAYİ  BAY/PB        TAŞOVA          9084397216
# 636987  AKTİFBANK-BAYİ  BAY/PB        TAŞOVA          4649228177
# 636988        HALKBANK  HLK/PV  GÜMÜŞHACIKÖY          7198356519
# 636989  AKTİFBANK-BAYİ  BAY/PB        TAŞOVA          2239951250
# 636990  AKTİFBANK-BAYİ  BAY/PB        TAŞOVA          8122050051
# 636991  AKTİFBANK-BAYİ  BAY/PB        TAŞOVA           946697585
# 636992       AKTİFBANK  AKT/PN      GÖYNÜCEK          6422892109
#
#        Tahsilat Tarihi  Nakit Tahsilat  Mahsuben Tahsilat  \
# 636983      2025-05-21         1013.01                NaN
# 636984      2025-05-23         1273.85                NaN
# 636985      2025-05-23         1013.01                NaN
# ...

# %%
#datafremein boyutunu görmek için
df_tahsilat.shape
# Out:
# (636993, 9)

# %%
#genel bilgilere(sutun isimleri, veri sayısı ve veri tipi) ulaşmak için info() metodu
df_tahsilat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636993 entries, 0 to 636992
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Şube                   636993 non-null  object
#  1   Kasa                   636993 non-null  object
#  2   İlçe                   636993 non-null  object
#  3   Söz.hsp.(bağımsız)     636993 non-null  int64
#  4   Tahsilat Tarihi        636993 non-null  datetime64[ns]
#  5   Nakit Tahsilat         523 non-null     float64
#  6   Mahsuben Tahsilat      7542 non-null    float64
#  7   Kredi Kartı Tahsilatı  0 non-null       float64
#  8   Banka Tahsilatı        628933 non-null  float64
# dtypes: datetime64[ns](1), float64(4), int64(1), object(3)
# memory usage: 43.7+ MB

# %%
essiz_müsteri = len(pd.unique(df_tahsilat['Söz.hsp.(bağımsız)']))
print(f"{essiz_müsteri} tane eşsiz müşteri var.")
# Out:
# 34835 tane eşsiz müşteri var.

# %%
df_tahsilat.describe()
# Out:
#        Söz.hsp.(bağımsız)                Tahsilat Tarihi  Nakit Tahsilat  \
# count        6.369930e+05                         636993      523.000000
# mean         5.019884e+09  2024-03-05 09:26:07.644856320      694.966635
# min          1.758320e+05            2023-01-01 00:00:00        7.450000
# 25%          2.532887e+09            2023-07-28 00:00:00      425.330000
# 50%          5.008502e+09            2024-02-26 00:00:00      524.670000
# 75%          7.525722e+09            2024-09-30 00:00:00      688.830000
# max          9.999600e+09            2025-05-31 00:00:00    11373.740000
# std          2.884435e+09                            NaN      758.319428
#
#        Mahsuben Tahsilat  Kredi Kartı Tahsilatı  Banka Tahsilatı
# count        7542.000000                    0.0    628933.000000
# mean         6180.182282                    NaN       372.629109
# min        -34508.950000                    NaN         0.010000
# ...

# %%
#null değer kontrolü 
df_tahsilat.isnull().sum()
# Out:
# Şube                          0
# Kasa                          0
# İlçe                          0
# Söz.hsp.(bağımsız)            0
# Tahsilat Tarihi               0
# Nakit Tahsilat           636470
# Mahsuben Tahsilat        629451
# Kredi Kartı Tahsilatı    636993
# Banka Tahsilatı            8060
# dtype: int64

# %% [markdown]
# df_tahsilat içiçn yaptığımız şeyleri df_tahsilaT_1 için yapacağız. bunu bir for döngüsü ile yazmamamın nedeni veriy her hücrede daha
# iyi görmek istemem.

# %%
df_tahsilat_1.head(10)
# Out:
#   Mali yıl/dönem      İl      İlçe  Söz.hsp.(bağımsız)  \
# 0       OCK 2023  AMASYA  GÖYNÜCEK          9374624783
# 1       OCK 2023  AMASYA  GÖYNÜCEK           236184905
# 2       OCK 2023  AMASYA  GÖYNÜCEK          9657731015
# 3       OCK 2023  AMASYA  GÖYNÜCEK          9554442880
# 4       OCK 2023  AMASYA  GÖYNÜCEK          6031642522
# 5       OCK 2023  AMASYA  GÖYNÜCEK          9404715439
# 6       OCK 2023  AMASYA  GÖYNÜCEK          3440240004
# 7       OCK 2023  AMASYA  GÖYNÜCEK          3100056422
# 8       OCK 2023  AMASYA  GÖYNÜCEK          2949666469
# 9       OCK 2023  AMASYA  GÖYNÜCEK          7940140859
#
#                  Hesap Sınıfı  Tahakkuk Tutar  \
# 0                      Mesken            5.03
# 1                      Mesken           26.46
# 2                      Mesken          121.53
# 3                      Mesken          117.49
# 4                      Mesken          170.30
# 5                      Mesken          132.63
# ...

# %%
df_tahsilat_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 917632 entries, 0 to 917631
# Data columns (total 22 columns):
#  #   Column                                Non-Null Count   Dtype
# ---  ------                                --------------   -----
#  0   Mali yıl/dönem                        917632 non-null  object
#  1   İl                                    917632 non-null  object
#  2   İlçe                                  917632 non-null  object
#  3   Söz.hsp.(bağımsız)                    917632 non-null  int64
#  4   Hesap Sınıfı                          917632 non-null  object
#  5   Tahakkuk Tutar                        917632 non-null  float64
#  6   Son Ödeme Tarihinden Önceki Tahsilat  623908 non-null  float64
#  7   Son Ödeme Tarihindeki Tahsilat        328193 non-null  float64
#  8   Son Ödeme (1)                         20902 non-null   float64
#  9   Son Ödeme (2)                         21664 non-null   float64
# ...

# %%
essiz_müsteri_1 = len(pd.unique(df_tahsilat_1['Söz.hsp.(bağımsız)']))
print(f"{essiz_müsteri_1} tane eşsiz müşteri var.")
# Out:
# 52367 tane eşsiz müşteri var.

# %%
df_tahsilat_1.describe()
# Out:
#        Söz.hsp.(bağımsız)  Tahakkuk Tutar  \
# count        9.176320e+05    9.176320e+05
# mean         5.010893e+09    5.085794e+02
# std          2.883691e+09    5.052666e+03
# min          1.758320e+05   -1.279328e+04
# 25%          2.513721e+09    1.101500e+02
# 50%          5.009565e+09    2.020700e+02
# 75%          7.509497e+09    3.215700e+02
# max          9.999760e+09    1.173258e+06
#
#        Son Ödeme Tarihinden Önceki Tahsilat  Son Ödeme Tarihindeki Tahsilat  \
# count                         623908.000000                   328193.000000
# mean                             206.312521                      547.264676
# std                             2855.301668                     3898.724314
# min                           -12793.280000                        0.000000
# 25%                                0.320000                      116.600000
# 50%                               44.220000                      210.990000
# ...

# %%
#null değer kontrolü 
df_tahsilat_1.isnull().sum()
# Out:
# Mali yıl/dönem                               0
# İl                                           0
# İlçe                                         0
# Söz.hsp.(bağımsız)                           0
# Hesap Sınıfı                                 0
# Tahakkuk Tutar                               0
# Son Ödeme Tarihinden Önceki Tahsilat    293724
# Son Ödeme Tarihindeki Tahsilat          589439
# Son Ödeme (1)                           896730
# Son Ödeme (2)                           895968
# Son Ödeme (3)                           898739
# Son Ödeme (4)                           900637
# Son Ödeme (5)                           910309
# Son Ödeme (6-10)                        871924
# Son Ödeme (10-20)                       869351
# Son Ödeme (20-30)                       888627
# Son Ödeme (30-60)                       894602
# Son Ödeme (60-90)                       910448
# Son Ödeme (90-120)                      913812
# Son Ödeme (120-150)                     915330
# ...

# %%
# Tahakkuk sayfaları ilçeleri temsil ediyor
print("Hamamözü Müşteri Sayısı:", essiz_müsteri)
print("Gümüşhacıköy Müşteri Sayısı:", essiz_müsteri_1)
print("Göynücek Müşteri Sayısı:", df_tahakkuk_2['sozlesme_hesap_no'].nunique())
# Out:
# Hamamözü Müşteri Sayısı: 34835
# Gümüşhacıköy Müşteri Sayısı: 52367
# Göynücek Müşteri Sayısı: 7128
